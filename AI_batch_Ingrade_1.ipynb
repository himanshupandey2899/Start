# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshupandey2899/Start/blob/master/AI_batch_Ingrade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Coding Cell
# to run press shift enter
# press ctrl s  -> to save the file
# python is case sensitive lang (it A and a are different)

# %% [markdown]
# # **Variables**

# %%
# it is a container which is used to store some values
a = 10

# %%
print(a) #print func is used to give output
# Out:
# 10

# %%
b = 10

# %%
print(10)
# Out:
# 10

# %%
a = 100

# %%
print(a)
# Out:
# 100

# %%
id(a) # it shows the memory location of variable
# Out:
# 11648520

# %%
id(b)
# Out:
# 11645640

# %%
c = 10
id(c)
# Out:
# 11645640

# %%
# Rule of naming variable
# rule 1 -> it should only contain alphabet numbers or underscore
# rule 2 -> it should only start with alphabet or underscore

# %%
umang = 1223
print(umang)
# Out:
# 1223

# %%
uMaNg = 12
print(uMaNg)
# Out:
# 12

# %%
q_q = 1232
print(q_q)
# Out:
# 1232

# %%
_uj = 435
print(_uj)
# Out:
# 435

# %%
# how to define one variable to one value
a = 10

# %%
# how to define multiple variable to multiple value
a,b,c = 10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
# how to define multiple variable to one value
x=y=z=12

# %%
print(z)
# Out:
# 12

# %%
# how to define one variable to multiple value
a = 1,22,4

# %%
a #this is tuple
# Out:
# (1, 22, 4)

# %% [markdown]
# # **Data Types in python**

# %%
# 1 int -> it means whole number
# 2 float -> Decimal number
# 3 string -> anything which will store as it is as we write
# 4 Bool -> True or False

# %%
a = 12
type(a)
# Out:
# int

# %%
b = 12.54
type(b)
# Out:
# float

# %%
# always write string in '' "" ''' '''
# for single line string we use '' ""
# for multiline string we use ''' ''' or """ """
c = '12mr3'
type(c)
# Out:
# str

# %%
d = True
type(d)
# Out:
# bool

# %%
prompt = """
you are python developer teach me basics of python which is required for agentic AI
"""

# %%
type(prompt)
# Out:
# str

# %% [markdown]
# # **Strings**

# %%
s = 'Artificial Intelengence'
